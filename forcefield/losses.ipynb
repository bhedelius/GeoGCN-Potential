# %%
import torch
import matplotlib.pyplot as plt

# %%
data = torch.load('./models/9_1000')

# %%
losses = data['loss']

# %%
plt.plot(losses[2000:])
plt.title("Learning curve at 1e-4")
plt.ylabel("Losses")
plt.xlabel("Steps")
plt.savefig("loss_1e-4.png")
